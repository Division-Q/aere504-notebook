# %% [markdown]
# # Maximum Likelihood Parameter Learning

# %%
using RDatasets
using PGFPlots
using Distributions
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /Users/sgdway/.julia/v0.5/StatsBase/src/scalarstats.jl:560 overwritten in module DataFrames at /Users/sgdway/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.

# %%
D = dataset("datasets", "iris")
# Out:
# 150×5 DataFrames.DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species     │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼─────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ "setosa"    │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ "setosa"    │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ "setosa"    │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ "setosa"    │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ "setosa"    │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ "setosa"    │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ "setosa"    │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ "setosa"    │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ "setosa"    │
# │ 10  │ 4.9         │ 3.1        │ 1.5         │ 0.1        │ "setosa"    │
# │ 11  │ 5.4         │ 3.7        │ 1.5         │ 0.2        │ "setosa"    │
# ⋮
# │ 139 │ 6.0         │ 3.0        │ 4.8         │ 1.8        │ "virginica" │
# │ 140 │ 6.9         │ 3.1        │ 5.4         │ 2.1        │ "virginica" │
# │ 141 │ 6.7         │ 3.1        │ 5.6         │ 2.4        │ "virginica" │
# │ 142 │ 6.9         │ 3.1        │ 5.1         │ 2.3        │ "virginica" │
# │ 143 │ 5.8         │ 2.7        │ 5.1         │ 1.9        │ "virginica" │
# │ 144 │ 6.8         │ 3.2        │ 5.9         │ 2.3        │ "virginica" │
# │ 145 │ 6.7         │ 3.3        │ 5.7         │ 2.5        │ "virginica" │
# │ 146 │ 6.7         │ 3.0        │ 5.2         │ 2.3        │ "virginica" │
# │ 147 │ 6.3         │ 2.5        │ 5.0         │ 1.9        │ "virginica" │
# │ 148 │ 6.5         │ 3.0        │ 5.2         │ 2.0        │ "virginica" │
# │ 149 │ 6.2         │ 3.4        │ 5.4         │ 2.3        │ "virginica" │
# │ 150 │ 5.9         │ 3.0        │ 5.1         │ 1.8        │ "virginica" │

# %%
d = D[:SepalLength]
Plots.Histogram(d)
# Out:
# PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],10,false,false,"fill=blue!10",:default)

# %%
dist = fit_mle(Normal, d)
g = Axis([
    Plots.Histogram(d, density=true),
    Plots.Linear(x->pdf(dist,x), (4,8))
]
)
display(g)
display(dist)
# Out:
# PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],10,true,false,"fill=blue!10",:default),PGFPlots.Plots.Linear(Real[4.0 4.0404 … 7.9596 8.0; 0.039905 0.0444626 … 0.0180507 0.0159021],"none",nothing,nothing,nothing,nothing,nothing)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")
# Distributions.Normal{Float64}(μ=5.843333333333335, σ=0.8253012917851409)

# %% [markdown]
# # Bayesian Parameter Learning

# %%
# small helper function for plotting Beta distributions
PGFPlots.plot(d::Beta) = plot(x->pdf(d, x), (0,1));

# %%
prior = Beta(6,2)
plot(prior)
# Out:
# TikzPictures.TikzPicture("\\begin{axis}\\addplot+ [mark = {none}]coordinates {\n(0.0, 0.0)\n(0.010101010101010102, 4.37183938781794e-9)\n(0.020202020202020204, 1.384713210182333e-7)\n(0.030303030303030304, 1.040676216724657e-6)\n(0.04040404040404041, 4.339719751499269e-6)\n(0.050505050505050504, 1.3104365511954242e-5)\n(0.06060606060606061, 3.2260962718464457e-5)\n(0.0707070707070707, 6.897888186099113e-5)\n(0.08080808080808081, 0.000133023830698588)\n(0.09090909090909091, 0.0002370790506225861)\n(0.10101010101010101, 0.0003970343933834652)\n(0.1111111111111111, 0.0006322432781813961)\n(0.12121212121212122, 0.0009657475291204844)\n(0.13131313131313133, 0.001424470093026666)\n(0.1414141414141414, 0.002039375637629304)\n(0.15151515151515152, 0.002845599030106493)\n(0.16161616161616163, 0.0038825416959939506)\n(0.1717171717171717, 0.005193935858457732)\n(0.18181818181818182, 0.006827876657930491)\n(0.1919191919191919, 0.008836822152111507)\n(0.20202020202020202, 0.011277561196330334)\n(0.21212121212121213, 0.014211149204274213)\n(0.2222222222222222, 0.017702811789079127)\n(0.23232323232323232, 0.02182181628478441)\n(0.24242424242424243, 0.026641311148151284)\n(0.25252525252525254, 0.03223813324084493)\n(0.26262626262626265, 0.03869258299198008)\n(0.2727272727272727, 0.046088167441030836)\n(0.2828282828282828, 0.05451131116110337)\n(0.29292929292929293, 0.06405103506257306)\n(0.30303030303030304, 0.07479860307708487)\n(0.31313131313131315, 0.08684713672191766)\n(0.32323232323232326, 0.10029119754471132)\n(0.3333333333333333, 0.11522633744855958)\n(0.3434343434343434, 0.13174861689746448)\n(0.35353535353535354, 0.14995409100215498)\n(0.36363636363636365, 0.16993826348627009)\n(0.37373737373737376, 0.191795508532905)\n(0.3838383838383838, 0.21561846051152048)\n(0.3939393939393939, 0.24149737158521817)\n(0.40404040404040403, 0.2695194371983756)\n(0.41414141414141414, 0.2997680894446484)\n(0.42424242424242425, 0.3323222583153358)\n(0.43434343434343436, 0.36725560082810704)\n(0.4444444444444444, 0.40463569803609434)\n(0.45454545454545453, 0.4445232199173499)\n(0.46464646464646464, 0.4869710581446626)\n(0.47474747474747475, 0.5320234267357437)\n(0.48484848484848486, 0.5797149305837721)\n(0.494949494949495, 0.6300696018683046)\n(0.5050505050505051, 0.6830999043465515)\n(0.5151515151515151, 0.7388057055250126)\n(0.5252525252525253, 0.7971732167114803)\n(0.5353535353535354, 0.8581739009474033)\n(0.5454545454545454, 0.9217633488206162)\n(0.5555555555555556, 0.9878801221584337)\n(0.5656565656565656, 1.0564445656011023)\n(0.5757575757575758, 1.1273575860556246)\n(0.5858585858585859, 1.2004994000299412)\n(0.5959595959595959, 1.2757282488474782)\n(0.6060606060606061, 1.3528790817420573)\n(0.6161616161616161, 1.4317622068331717)\n(0.6262626262626263, 1.512161909981624)\n(0.6363636363636364, 1.5938350415255245)\n(0.6464646464646465, 1.676509570896667)\n(0.6565656565656566, 1.7598831091172447)\n(0.6666666666666666, 1.8436213991769548)\n(0.6767676767676768, 1.9273567742904478)\n(0.6868686868686869, 2.0106865840351507)\n(0.696969696969697, 2.0931715883694526)\n(0.7070707070707071, 2.1743343195312472)\n(0.7171717171717171, 2.2536574118168513)\n(0.7272727272727273, 2.3305818992402747)\n(0.7373737373737373, 2.4045054810728597)\n(0.7474747474747475, 2.4747807552632897)\n(0.7575757575757576, 2.5407134197379384)\n(0.7676767676767676, 2.601560441581625)\n(0.7777777777777778, 2.656528194098686)\n(0.7878787878787878, 2.704770561754444)\n(0.797979797979798, 2.7453870129970217)\n(0.8080808080808081, 2.777420640959532)\n(0.8181818181818182, 2.799856172042622)\n(0.8282828282828283, 2.811617942377394)\n(0.8383838383838383, 2.811567842168664)\n(0.8484848484848485, 2.798503227918617)\n(0.8585858585858586, 2.771154802530804)\n(0.8686868686868687, 2.7281844632945083)\n(0.8787878787878788, 2.6681831177494746)\n(0.8888888888888888, 2.5896684674310047)\n(0.898989898989899, 2.491082759495417)\n(0.9090909090909091, 2.370790506225866)\n(0.9191919191919192, 2.22707617241852 ...

# %%
prior
# Out:
# Distributions.Beta{Float64}(α=6.0, β=2.0)

# %%
posterior(d::Beta, x) = Beta(d.α + sum(x .== 1), d.β + sum(x .== 0))
# Out:
# posterior (generic function with 1 method)

# %%
# The posterior function is provided by distributions.jl
post = posterior(prior, [0, 0, 1])
# Out:
# Distributions.Beta{Float64}(α=7.0, β=4.0)

# %%
plot(post)
# Out:
# TikzPictures.TikzPicture("\\begin{axis}\\addplot+ [mark = {none}]coordinates {\n(0.0, 0.0)\n(0.010101010101010102, 8.654475678240122e-10)\n(0.020202020202020204, 5.371031648844565e-8)\n(0.030303030303030304, 5.930670038823788e-7)\n(0.04040404040404041, 3.2291877664333097e-6)\n(0.050505050505050504, 1.1933452849444127e-5)\n(0.06060606060606061, 3.4507927954413905e-5)\n(0.0707070707070707, 8.423920446171762e-5)\n(0.08080808080808081, 0.00018164633244226907)\n(0.09090909090909091, 0.00035624199943288685)\n(0.10101010101010101, 0.0006482351172144718)\n(0.1111111111111111, 0.0011101116544200104)\n(0.12121212121212122, 0.
094232188)\n(0.7878787878787878, 1.9177325295239787)\n(0.797979797979798, 1.788195795537372)\n(0.8080808080808081, 1.6533441364138532)\n(0.8181818181818182, 1.5145728353649035)\n(0.8282828282828283, 1.3733853585020583)\n(0.8383838383838383, 1.2313769984386225)\n(0.8484848484848485, 1.0902146865587177)\n(0.8585858585858586, 0.9516126268328265)\n(0.8686868686868687, 0.8173033877087855)\n(0.8787878787878788, 0.6890040719235087)\n(0.8888888888888888, 0.5683771670630463)\n(0.898989898989899, 0.45698566234756915)\n(0.9090909090909091, 0.3562419994328877)\n(0.9191919191919192, 0.26735040700166607)\n(0.9 ...

# %% [markdown]
# # Nonparametric Parameter Learning

# %%
bandwith = 0.2
# kernel
K(x) = pdf(Normal(0,bandwith), x)
# nonparametric density function
p(x) = sum([K(x - o) for o in d])/length(d)
# plot result, comparing with histogram
g = Axis([
    Plots.Histogram(d, density=true, bins=30),
    Plots.Linear(p, (4,8))
])
# Out:
# PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],30,true,false,"fill=blue!10",:default),PGFPlots.Plots.Linear(Real[4.0 4.0404 … 7.9596 8.0; 0.0109757 0.0158349 … 0.0386251 0.030995],"none",nothing,nothing,nothing,nothing,nothing)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")

# %%
bandwidths = [0.01, 0.1, 0.2, 0.5]
gp = GroupPlot(2,2)
for bandwidth in bandwidths
    # kernel
    K(x) = pdf(Normal(0,bandwidth), x)
    # nonparametric density function
    p(x) = sum([K(x - o) for o in d])/length(d)
    # plot result, comparing with histogram
    g = Axis([
        Plots.Histogram(d, density=true, bins=30),
        Plots.Linear(p, (4,8))
        ], title = bandwidth)
    push!(gp, g)
end
gp
# Out:
# WARNING: Method definition K(Any) in module Main at In[11]:3 overwritten at In[12]:5.
# WARNING: Method definition p(Any) in module Main at In[11]:5 overwritten at In[12]:7.
# WARNING: Method definition K(Any) in module Main at In[12]:5 overwritten at In[12]:5.
# WARNING: Method definition p(Any) in module Main at In[12]:7 overwritten at In[12]:7.
# WARNING: Method definition K(Any) in module Main at In[12]:5 overwritten at In[12]:5.
# WARNING: Method definition p(Any) in module Main at In[12]:7 overwritten at In[12]:7.
# WARNING: Method definition K(Any) in module Main at In[12]:5 overwritten at In[12]:5.
# WARNING: Method definition p(Any) in module Main at In[12]:7 overwritten at In[12]:7.
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],30,true,false,"fill=blue!10",:default),PGFPlots.Plots.Linear(Real[4.0 4.0404 … 7.9596 8.0; 0.0109757 0.0158349 … 0.0386251 0.030995],"none",nothing,nothing,nothing,nothing,nothing)],0.01,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],30,true,false,"fill=blue!10",:default),PGFPlots.Plots.Linear(Real[4.0 4.0404 … 7.9596 8.0; 0.0109757 0.0158349 … 0.0386251 0.030995],"none",nothing,nothing,nothing,nothing,nothing)],0.1,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],30,true,false,"fill=blue!10",:default),PGFPlots.Plots.Linear(Real[4.0 4.0404 … 7.9596 8.0; 0.0109757 0.0158349 … 0.0386251 0.030995],"none",nothing,nothing,nothing,nothing,nothing)],0.2,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9  …  6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],30,true,false,"fill=blue!10",:default),PGFPlots.Plots.Linear(Real[4.0 4.0404 … 7.9596 8.0; 0.0109757 0.0158349 … 0.0386251 0.030995],"none",nothing,nothing,nothing,nothing,nothing)],0.5,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")],(2,2),nothing,nothing)
