# %%
using TikzPictures
using PGFPlots
using Distributions
using BayesNets
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at U:\.julia\v0.5\StatsBase\src\scalarstats.jl:560 overwritten in module DataFrames at U:\.julia\v0.5\DataFrames\src\abstractdataframe\abstractdataframe.jl:407.

# %% [markdown]
# # Piecewise Constant Distributions

# %%
# define a normal distribution with mean 3 and standard deviation 2
dist = Normal(3,2)
# generate 1000 samples
d = rand(dist, 1000)
# try out histograms with a variety of different number of bins
bins = [3 10 50 1000]
g = GroupPlot(2,2)
for i = 1:length(bins)
    push!(g, Axis(Plots.Histogram(d, bins=bins[i]), ymin=0))
end
g
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[3.59374,2.07488,1.46814,3.58948,1.72245,1.52431,-1.38342,6.30907,2.73718,4.31341  …  3.55353,2.58582,1.87347,1.40074,2.95667,3.40596,-1.22402,4.27022,0.585637,2.00718],3,false,false,"fill=blue!10",:default)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,0,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[3.59374,2.07488,1.46814,3.58948,1.72245,1.52431,-1.38342,6.30907,2.73718,4.31341  …  3.55353,2.58582,1.87347,1.40074,2.95667,3.40596,-1.22402,4.27022,0.585637,2.00718],10,false,false,"fill=blue!10",:default)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,0,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[3.59374,2.07488,1.46814,3.58948,1.72245,1.52431,-1.38342,6.30907,2.73718,4.31341  …  3.55353,2.58582,1.87347,1.40074,2.95667,3.40596,-1.22402,4.27022,0.585637,2.00718],50,false,false,"fill=blue!10",:default)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,0,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[3.59374,2.07488,1.46814,3.58948,1.72245,1.52431,-1.38342,6.30907,2.73718,4.31341  …  3.55353,2.58582,1.87347,1.40074,2.95667,3.40596,-1.22402,4.27022,0.585637,2.00718],1000,false,false,"fill=blue!10",:default)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,0,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")],(2,2),nothing,nothing)

# %% [markdown]
# Of course, these plots are not of densities (they do not integrate to 1).

# %% [markdown]
# # Mixture Model
# This example will focus on Gaussian mixture components, but the code can support components from other distributions

# %%
function mix_pdf(d::MixtureModel, x)
    sum([probs(d.prior)[i] * pdf(d.components[i], x) for i in 1:length(d.components)])
end;

# %%
dist = MixtureModel([Normal(-3,1), Normal(4,2)], [0.8, 0.2])
# Out:
# MixtureModel{Distributions.Normal{Float64}}(K = 2)
# components[1] (prior = 0.8000): Distributions.Normal{Float64}(μ=-3.0, σ=1.0)
# components[2] (prior = 0.2000): Distributions.Normal{Float64}(μ=4.0, σ=2.0)

# %%
function draw_rand(d::MixtureModel, n)
    # create an array c holding random components (based on weights)
    c = wsample(1:length(d.components), probs(d.prior), n)
    # randomly generate sample from appropriate component distribution
    convert(Vector{Float64}, [rand(d.components[c[i]]) for i = 1:n]) # what is the array holding inside each element?
end
# Out:
# draw_rand (generic function with 1 method)

# %%
d = draw_rand(dist, 1000)
a = Axis(Plots.Histogram(d, bins=50), ymin=0, ylabel="Counts", width="25cm", height="8cm")
# Out:
# PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Histogram(Real[-1.54268,6.63007,-2.31362,-4.53335,-2.56339,3.53594,2.67007,-3.55068,0.254432,-2.98242  …  -2.678,-2.31972,-3.52025,-3.50749,-2.64166,-0.207879,-2.80604,-2.7292,0.469707,-4.46256],50,false,false,"fill=blue!10",:default)],nothing,nothing,nothing,"Counts",nothing,nothing,nothing,nothing,nothing,0,nothing,nothing,nothing,nothing,nothing,nothing,"25cm","8cm",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")

# %% [markdown]
# Note the two modes

# %% [markdown]
# # Conditional Probability Distributions

# %% [markdown]
# # Binary
# There are many types of conditional probability distributions. Here we'll focus on those with binary variables whose distribution can be specified using a table.

# %%
target = :C
parents = [:B, :S]
parental_ncategories = [2, 2] # B and S can each be 0 or 1
distributions = [Bernoulli(0.8), # B = 0, S = 0
                 Bernoulli(0.2), # B = 1, S = 0
                 Bernoulli(0.3), # B = 0, S = 1
                 Bernoulli(0.5)] # B = 1, S = 1
cpd = CategoricalCPD(target, parents, parental_ncategories, distributions);

# %% [markdown]
# Let's make an assignment of variables to values.

# %%
a = Assignment(:B=>1, :S=>2)
# Out:
# Dict{Symbol,Any} with 2 entries:
#   :S => 2
#   :B => 1

# %%
pdf(cpd(a), true)
# Out:
# 0.3

# %% [markdown]
# # Linear Gaussian
# $$\mathcal{N}(\mu = a\cdot x + b, \sigma)$$
# The constructor of CPDs. Normal takes a function mapping an assignment to a tuple of parameters (i.e., mean and variance for the Normal distribution

# %%
a = [5.0]; b = 0.0; s = 1.0
cpd = LinearGaussianCPD(:y, [:x], a, b, s)

PGFPlots.Axis(Plots.Linear(x->pdf(cpd(:x=>1.0), x), (-10, 10)), width="25cm", height="8cm") # confused with x?
# Out:
# PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[-10.0 -9.79798 … 9.79798 10.0; 5.53071e-50 1.12192e-48 … 3.99989e-6 1.48672e-6],"none",nothing,nothing,nothing,nothing,nothing)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"25cm","8cm",nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")

# %%
g = GroupPlot(3,1)
for x in -1:1
    push!(g, Plots.Linear(j->pdf(cpd(:x=>x), j), (-10, 10))) # completely confused with x?
end
g
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[-10.0 -9.79798 … 9.79798 10.0; 1.48672e-6 3.99989e-6 … 1.12192e-48 5.53071e-50],"none",nothing,nothing,nothing,nothing,nothing)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[-10.0 -9.79798 … 9.79798 10.0; 7.6946e-23 5.68442e-22 … 5.68442e-22 7.6946e-23],"none",nothing,nothing,nothing,nothing,nothing)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis"),PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[-10.0 -9.79798 … 9.79798 10.0; 5.53071e-50 1.12192e-48 … 3.99989e-6 1.48672e-6],"none",nothing,nothing,nothing,nothing,nothing)],nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,nothing,"axis")],(3,1),nothing,nothing)

# %% [markdown]
# # Bayesian Networks
# A Bayesian network is a directed acyclic graph comprised of conditional probability distributions.

# %%
bn = DiscreteBayesNet()
push!(bn, DiscreteCPD(:B, [0.1, 0.9]))
push!(bn, DiscreteCPD(:S, [0.5, 0.5]))
push!(bn, rand_cpd(bn, 2, :E, [:B, :S]))
push!(bn, rand_cpd(bn, 2, :D, [:E]))
push!(bn, rand_cpd(bn, 2, :C, [:E]))
# Out:
# BayesNets.BayesNet{BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}}({5, 4} directed graph,BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}[BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}(:B,Symbol[],Int64[],Distributions.Categorical{Float64}[Distributions.Categorical{Float64}(K=2, p=[0.1,0.9])]),BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}(:S,Symbol[],Int64[],Distributions.Categorical{Float64}[Distributions.Categorical{Float64}(K=2, p=[0.5,0.5])]),BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}(:E,Symbol[:B,:S],[2,2],Distributions.Categorical{Float64}[Distributions.Categorical{Float64}(K=2, p=[0.225924,0.774076]),Distributions.Categorical{Float64}(K=2, p=[0.90318,0.0968205]),Distributions.Categorical{Float64}(K=2, p=[0.97603,0.0239695]),Distributions.Categorical{Float64}(K=2, p=[0.64946,0.35054])]),BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}(:C,Symbol[:E],[2],Distributions.Categorical{Float64}[Distributions.Categorical{Float64}(K=2, p=[0.869468,0.130532]),Distributions.Categorical{Float64}(K=2, p=[0.347232,0.652768])]),BayesNets.CPDs.CategoricalCPD{Distributions.Categorical{Float64}}(:D,Symbol[:E],[2],Distributions.Categorical{Float64}[Distributions.Categorical{Float64}(K=2, p=[0.887106,0.112894]),Distributions.Categorical{Float64}(K=2, p=[0.635653,0.364347])])],Dict(:S=>2,:C=>4,:B=>1,:D=>5,:E=>3))

# %% [markdown]
# Let's compute the probability of an assignment using the chain rule

# %%
a = Assignment(
    :B=>1,
    :S=>2,
    :E=>1,
    :D=>2,
    :C=>2)
# Out:
# Dict{Symbol,Any} with 5 entries:
#   :S => 2
#   :C => 2
#   :B => 1
#   :D => 2
#   :E => 1

# %% [markdown]
# Here are conditional probabilities.

# %%
[pdf(get(bn, name), a) for name in names(bn)]
# Out:
# 5-element Array{Float64,1}:
#  0.1
#  0.5
#  0.97603
#  0.130532
#  0.112894

# %%
prod([pdf(get(bn, name), a) for name in names(bn)])
# Out:
# 0.0007191556657905769

# %% [markdown]
# The library implements this for you:

# %%
pdf(bn, a)
# Out:
# 0.0007191556657905769
